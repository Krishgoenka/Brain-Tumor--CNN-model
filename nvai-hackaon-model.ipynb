# %% [markdown]
# # nvAI Brain Tumor Detection Model

# %% [markdown]
# # # **Lets Start -  Members**
# # >👨‍💻 Parth Vastavik - Full Stack Developer
# # >👨‍💻 Krish Goenka - AI Model Developer
# # > 👨‍💻 Anustup Karnar - AI Model Developer
# # > 👨‍💻 Rajarshi Ghosh - AI Model Developer
# # > 👩‍💻 Palak Jain - UI/UX Designer, Presentation Head**

# %% [markdown]
# # All imports

# %%
import os
import keras 
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # One Hot Encoding the Target Classes

# %%
encoder = OneHotEncoder()
encoder.fit([[0], [1]]) 

# 0 - Tumor
# 1 - Normal
# Out:
# OneHotEncoder()

# %% [markdown]
# # Creating 3 Important Lists --
# 1. data list for storing image data in numpy array form
# 2. paths list for storing paths of all images
# 3. result list for storing one hot encoded form of target class whether normal or tumor

# %%
# This cell updates result list for images with tumor

data = []
paths = []
result = []

for r, d, f in os.walk(r'../input/brain-mri-images-for-brain-tumor-detection/yes'):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[0]]).toarray())

# %%
# This cell updates result list for images without tumor

paths = []
for r, d, f in os.walk(r"../input/brain-mri-images-for-brain-tumor-detection/no"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[1]]).toarray())

# %%
data = np.array(data)
data.shape
# Out:
# (139, 128, 128, 3)

# %%
result = np.array(result)
result = result.reshape(139,2)

# %% [markdown]
# # Splitting the Data into Training & Testing

# %%
x_train,x_test,y_train,y_test = train_test_split(data, result, test_size=0.2, shuffle=True, random_state=0)

# %% [markdown]
# # Model Building

# %% [markdown]
# Batch normalization is a technique for training very deep neural networks that standardizes the inputs to a layer for each mini-batch. This has the effect of stabilizing the learning process and dramatically reducing the number of training epochs required to train deep networks.

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(2, 2), input_shape=(128, 128, 3), padding = 'Same'))
model.add(Conv2D(32, kernel_size=(2, 2),  activation ='relu', padding = 'Same'))


model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))

model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))

model.compile(loss = "categorical_crossentropy", optimizer='Adamax')
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 32)      416
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      4128
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 128, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 64)        8256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 64)        16448
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 65536)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               33554944
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 33,585,602
# Trainable params: 33,585,410
# Non-trainable params: 192
# _________________________________________________________________
# None

# %%
y_train.shape
# Out:
# (111, 2)

# %%
history = model.fit(x_train, y_train, epochs = 30, batch_size = 40, verbose = 1,validation_data = (x_test, y_test))
# Out:
# Epoch 1/30
# 3/3 [==============================] - 3s 1s/step - loss: 22.6524 - val_loss: 21.2492
# Epoch 2/30
# 3/3 [==============================] - 3s 1s/step - loss: 7.6110 - val_loss: 8.0353
# Epoch 3/30
# 3/3 [==============================] - 3s 1s/step - loss: 6.3476 - val_loss: 4.9919
# Epoch 4/30
# 3/3 [==============================] - 3s 1s/step - loss: 1.4349 - val_loss: 9.5334
# Epoch 5/30
# 3/3 [==============================] - 3s 1s/step - loss: 2.2792 - val_loss: 7.9434
# Epoch 6/30
# 3/3 [==============================] - 3s 1s/step - loss: 1.7468 - val_loss: 7.2041
# Epoch 7/30
# 3/3 [==============================] - 3s 977ms/step - loss: 0.7022 - val_loss: 7.8568
# Epoch 8/30
# 3/3 [==============================] - 3s 965ms/step - loss: 0.3253 - val_loss: 6.6896
# Epoch 9/30
# 3/3 [==============================] - 3s 966ms/step - loss: 0.1752 - val_loss: 5.2444
# Epoch 10/30
# 3/3 [==============================] - 3s 963ms/step - loss: 0.0789 - val_loss: 4.9109
# Epoch 11/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.0030 - val_loss: 4.6623
# Epoch 12/30
# 3/3 [==============================] - 3s 978ms/step - loss: 0.0083 - val_loss: 4.2061
# Epoch 13/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1827 - val_loss: 3.7114
# Epoch 14/30
# 3/3 [==============================] - 3s 995ms/step - loss: 0.0281 - val_loss: 3.1663
# Epoch 15/30
# 3/3 [==============================] - 3s 959ms/step - loss: 0.3844 - val_loss: 3.5843
# Epoch 16/30
# 3/3 [==============================] - 3s 985ms/step - loss: 5.4317e-04 - val_loss: 3.8449
# Epoch 17/30
# 3/3 [==============================] - 3s 975ms/step - loss: 0.0015 - val_loss: 4.0015
# Epoch 18/30
# 3/3 [==============================] - 3s 993ms/step - loss: 3.5863e-06 - val_loss: 4.0932
# Epoch 19/30
# 3/3 [==============================] - 3s 937ms/step - loss: 0.2702 - val_loss: 3.6119
# Epoch 20/30
# 3/3 [==============================] - 3s 948ms/step - loss: 0.2463 - val_loss: 3.1407
# Epoch 21/30
# 3/3 [==============================] - 3s 1s/step - loss: 2.1734e-04 - val_loss: 2.8480
# Epoch 22/30
# 3/3 [==============================] - 3s 942ms/step - loss: 0.0017 - val_loss: 2.6429
# Epoch 23/30
# 3/3 [==============================] - 3s 973ms/step - loss: 1.0659e-04 - val_loss: 2.4661
# Epoch 24/30
# 3/3 [==============================] - 3s 958ms/step - loss: 0.0285 - val_loss: 2.3613
# Epoch 25/30
# 3/3 [==============================] - 3s 969ms/step - loss: 9.7191e-07 - val_loss: 2.2852
# Epoch 26/30
# 3/3 [==============================] - 3s 965ms/step - loss: 0.0903 - val_loss: 2.1636
# Epoch 27/30
# 3/3 [==============================] - 3s 966ms/step - loss: 0.0013 - val_loss: 1.9609
# Epoch 28/30
# 3/3 [==============================] - 3s 1s/step - loss: 5.1633e-04 - val_loss: 1.8324
# Epoch 29/30
# 3/3 [==============================] - 3s 1s/step - loss: 2.7285e-05 - val_loss: 1.7394
# Epoch 30/30
# 3/3 [==============================] - 3s 986ms/step - loss: 8.5640e-06 - val_loss: 1.6700

# %% [markdown]
# # Plotting Losses

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Test', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# # Just Checking the Model

# %%
def names(number):
    if number==0:
        return 'Tumor Detected'
    else:
        return 'No Tumor Detected'

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"../input/brain-mri-images-for-brain-tumor-detection/no/N17.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence | Result- This Is ' + names(classification))
# Out:
# 100.0% Confidence | Result- This Is No Tumor Detected

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"../input/brain-mri-images-for-brain-tumor-detection/yes/Y1.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence | Result- This Is A ' + names(classification))
# Out:
# 100.0% Confidence | Result- This Is A Tumor Detected

# %% [markdown]
# # Model Complete just have tset model for taking input from User . And to implement model in Frontend nvAI Website
